# %% [markdown]
# # Pulmonary Fibrosis - Predicting Progression from Baseline CT Scans and Patient Characteristics

# %% [markdown]
# ## Final -  Best Model Runs

# %%
import os
import cv2
import pydicom
import pylibjpeg
import gdcm
import pandas as pd
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 
import random
import math
from tqdm.notebook import tqdm
from tensorflow.keras.layers import (
    Dense, Dropout, Activation, Flatten, Input, BatchNormalization, GlobalAveragePooling2D, Add, Conv2D, MaxPooling2D, AveragePooling2D, 
    LeakyReLU, Concatenate 
) 
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error
from sklearn import preprocessing

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Model
from tensorflow.keras.utils import Sequence
import tensorflow.keras.applications as tfa

from tensorflow.keras.optimizers import Nadam
import seaborn as sns
from PIL import Image
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import Sequence

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.callbacks import EarlyStopping

from numpy import loadtxt
from tensorflow.keras.models import load_model

from tensorflow.keras.layers import concatenate

from scipy import stats
import seaborn as sns

import datetime


def seed_everything(seed=2020):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything(42)

# %%
#Uncomment this code for training on a multi-GPU VM
#mirrored_strategy = tf.distribute.MirroredStrategy()

# %%
BATCH_SIZE = 8
SAVE_BEST = True
MODEL_CLASS = 'b5'
EPOCHS=30

# %% [markdown]
# # Preparing the data that will fit the models #
# We have created a separated notebook for EDA of tabular data and images. Here we show the functions and classes that allow us to extract the data that will go into the models.

# %%
#read the tabular data from train.csv
df_import = pd.read_csv('./train.csv')

# %% [markdown]
# ### Calculate output value (Least Squares Slope of FVC) for all patients

# %%
def create_output(df):

    #Create containers to store the data 
    target = pd.DataFrame(columns=['Patient', 'Slope']) # dataframe with target output 

    #Calculate slope for each patient in the train set
    for p in df.Patient.unique():
        #subsample the training set
        sub = df[df.Patient == p]
        #get the FVC for the p-patient
        fvc = sub.FVC.values
        #get the Weeks for the p-patient
        weeks = sub.Weeks.values

        #calculate the slope using linar regression
        slope, intercept, r_value, p_value, std_err = stats.linregress(weeks, fvc)

        #fill out dictionaries with corresponding data
        target = target.append({'Patient' : p, 'Slope' : slope}, ignore_index = True)
        
    return target

# %%
target = create_output(df_import)

# %% [markdown]
# ### Scale the output variable

# %%
slope=target.Slope.values.copy()
slope = slope.reshape(-1, 1)
slope_scaler = MinMaxScaler()
scaled_slope = slope_scaler.fit_transform(slope)

# %% [markdown]
# ### Process Input Dataframe to Generate Baseline Tabular Data for Each Patient

# %%
tabular = pd.DataFrame(columns =['Patient', 'FVC', 'Percent', 'Age', 'Sex', 'SS1', 'SS2'])

for p in df_import.Patient.unique():
    
    sub=df_import[df_import.Patient ==p]
    
    f = sub.FVC.values[0]
    pct = sub.Percent.values[0]
    a = sub.Age.values[0]
    s = sub.Sex.values[0]
    ss = sub.SmokingStatus.values[0]
    
    #encode the categorical variables
    
    if s == 'male':
        s_enc = 0
    else:
        s_enc = 1
    
    if ss == 'Never smoked':
        #encode as 0,0
        ss_1 = 0
        ss_2 = 0
    elif ss == 'Ex-smoker':
        #encode as 1, 1
        ss_1 = 1
        ss_2 = 1
    elif ss == 'Currently smokes':
        #encode as 0,1
        ss_1 = 0
        ss_2 = 1

    
    tabular = tabular.append({'Patient': p, 'FVC': f, 'Percent': pct, 'Age': a, 'Sex': s_enc, 'SS1': ss_1, 'SS2': ss_2}, ignore_index=True)

# %% [markdown]
# ### Scale the tabular values

# %%
fvc = tabular.FVC.values.reshape(-1, 1)
pct = tabular.Percent.values.reshape(-1, 1)
age = tabular.Age.values.reshape(-1, 1)

fvc_scaler = MinMaxScaler()
pct_scaler = MinMaxScaler()
age_scaler = MinMaxScaler()

fvc_scaled = fvc_scaler.fit_transform(fvc)
pct_scaled = pct_scaler.fit_transform(pct)
age_scaled = age_scaler.fit_transform(age)

sex = tabular.Sex.values.reshape(-1, 1)
ss1 = tabular.SS1.values.reshape(-1, 1)
ss2 = tabular.SS2.values.reshape(-1, 1)

# %% [markdown]
# ### Recombine processed data back into Pandas before holdback

# %%
df_processed = pd.DataFrame()
df_processed['Patient'] = df_import.Patient.unique()
df_processed['Target'] = scaled_slope
df_processed['FVC']= fvc_scaled
df_processed['PCT'] = pct_scaled
df_processed['Age'] = age_scaled
df_processed['Sex'] = sex
df_processed['SS1'] = ss1
df_processed['SS2'] = ss2

# %% [markdown]
# ### Make dictionaries for train test data selection

# %%
target={}
TAB = {}
for p in df_processed.Patient.unique():
    sub = df_processed[df_processed.Patient == p]
    target[p] = sub.Target.values[0]
    
    vector = [sub.FVC.values[0]]
    vector.append(sub.PCT.values[0])
    vector.append(sub.Age.values[0])
    vector.append(sub.Sex.values[0])
    vector.append(sub.SS1.values[0])
    vector.append(sub.SS2.values[0])
    vector = np.array(vector)
    
    TAB[p] = vector

# %% [markdown]
# ### Select some patients to hold back to assess model performance

# %%
#get the full list of patient IDs
patient_ID = df_processed.Patient.unique()

# %%
#split the remaining patient IDs into train and test 
split = train_test_split(patient_ID, test_size=0.25, random_state=42)

(train_ID, test_ID) = split

# %% [markdown]
# ### Image Processing

# %% [markdown]
# Process dicom images into format that CNN can use

# %%
#Function to process images
def get_img(path):
    """This function receives a path as an input,
    and outputs a resized CT scan image that was
    also transformed into Hounsfield units. The information 
    needed to transform the voxels is included in the
    metadata contained in each CT scan"""

    pd = pydicom.dcmread(path)
    r = cv2.resize((pd.pixel_array - pd.RescaleIntercept) / (pd.RescaleSlope * 1000), (512, 512))

    return r

# %% [markdown]
# Load the masked images (alternate approach)

# %%
def get_masked_img(path):
    """This function receives a path as an input,
    and outputs a resized CT scan image that was
    also transformed into Hounsfield units. The information 
    needed to transform the voxels is included in the
    metadata contained in each CT scan"""
    i = np.load(path)
    return i

# %% [markdown]
# Sample images for each patient and create tables of images combined with target output and tabular data (can be used to sample n_images for each patient or train on all available images)

# %%
class image_data(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size=BATCH_SIZE):
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in df_import.Patient.unique():
            self.train_data[p] = os.listdir(f'train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size)
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0]
                img = get_img(f'train/{k}/{i}')
                x.append(img)
                a.append(self.a[k])
                tab.append(self.tab[k])
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab)
        x = np.expand_dims(x, axis=-1)
        return [x], a

# %%
class masked_image_data(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size=BATCH_SIZE):
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in df_import.Patient.unique():
            self.train_data[p] = os.listdir(f'train_masked/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size)
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0]
                img = get_masked_img(f'train_masked/{k}/{i}')
                x.append(img)
                a.append(self.a[k])
                tab.append(self.tab[k])
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab)
        x = np.expand_dims(x, axis=-1)
        return [x], a

# %%
class tab_data(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size=BATCH_SIZE):
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in df_import.Patient.unique():
            self.train_data[p] = os.listdir(f'train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size)
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0]
                img = get_img(f'train/{k}/{i}')
                x.append(img)
                a.append(self.a[k])
                tab.append(self.tab[k])
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab)
        x = np.expand_dims(x, axis=-1)
        return [tab], a

# %%
class combined_data(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size=BATCH_SIZE):
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in df_import.Patient.unique():
            self.train_data[p] = os.listdir(f'train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size)
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0]
                img = get_img(f'train/{k}/{i}')
                x.append(img)
                a.append(self.a[k])
                tab.append(self.tab[k])
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab)
        x = np.expand_dims(x, axis=-1)
        return [x, tab], a

# %% [markdown]
# ## Model Result Evaluation Functions

# %% [markdown]
# ### Predict the slope for patient based on mean of that patient's scans (n_images) - more useful for inference on a given patient

# %%
def compare_slope_per_pt(model_input, data_type, df_input = df_import, patient_IDs=test_ID, image_type = 'unmasked', target=target, TAB=TAB, slope_scaler=slope_scaler, n_images=24):
    '''
    df_input: held back data frame of patients from original sample
    model_input: name of trained model for inference
    data_type: type of data for prediction - either 'image' for CNN, 'text' for MLP, or 'combined' for combined
    '''
    q = 0.5

    slopes = pd.DataFrame(columns=['Patient', 'Calculated_Slope', 'Lower_CI', 'Upper_CI', 'Predicted_Slope', 'Within_Range'])
    
    if image_type == 'unmasked':
        img_dir = 'train'
    if image_type == 'masked':
        img_dir = 'train_masked'
        
    
    df_data={}
    
    for p in patient_IDs:
        #print(p)
        a = []
        
        df_data[p] = os.listdir(f'./{img_dir}/{p}/')
        #print(os.listdir(f'./train/{p}/'))

        for n in range(0, n_images):
            tab= []
            img= []
            
            if data_type!='text':
                i = np.random.choice(df_data[p], size = 1)[0] #select a random image from the patient directory
                if image_type == 'unmasked':
                    image = get_img(f"./{img_dir}/{p}/{i}") #apply function to process the images
                if image_type == 'masked':
                    image = get_masked_img(f"./{img_dir}/{p}/{i}") #apply function to process the images
                    
                img.append(image)
            
            #image = np.array(img)
            img = np.expand_dims(img, axis = -1)
            
            tab.append(TAB[p])
            tab = np.array(tab)

            #Use the saved model to predict the linear decay of the patient
            #Per the model, this is going to give us an estimated slope per patient

            if data_type=='image':
                _a = model_input.predict([img])
                a.append(_a)

            if data_type=='text':
                _a = model_input.predict([tab])
                a.append(_a)

            if data_type=='combined':
                _a = model_input.predict([img, tab])
                a.append(_a)
                

        slope_p = np.mean(a)
        
        slope_p = slope_p.reshape(-1, 1)
        
        slope_p = slope_scaler.inverse_transform(slope_p)
        
        slope_p = slope_p[0][0]

        #subsample the training set
        sub = df_input[df_input.Patient == p]
        #get the FVC for the p-patient
        fvc = sub.FVC.values
        #get the Weeks for the p-patient
        weeks = sub.Weeks.values

        #calculate the slope using linar regression
        slope, intercept, r_value, p_value, std_err = stats.linregress(weeks, fvc)

        slope_calc=slope
        
        CI = 2.58*std_err
        
        ci_1 = slope_calc + CI
        
        ci_2 = slope_calc - CI
        
        upper_CI = max(ci_1, ci_2)
        
        lower_CI = min(ci_1, ci_2)
        
        if lower_CI < slope_p < upper_CI:
            compare = 'Yes'
        else:
            compare = 'No'
        
        slopes = slopes.append({'Patient' : p, 'Calculated_Slope' : slope_calc, 'Lower_CI' : lower_CI, 'Upper_CI': upper_CI, 
                                          'Predicted_Slope': slope_p, 'Within_Range': compare}, ignore_index = True) 
    
    return slopes

# %%
def predictions_for_graph(slope_best, df_import = df_import):
    
    fvc_plot = pd.DataFrame(columns=['Patient', 'Week', 'FVC_true', 'FVC_OLS', 
                                     'FVC_upperCI', 'FVC_lowerCI', 'FVC_predicted', 'Within_range'])

    for p in test_ID:
            sub = df_import[df_import.Patient == p]
            #get the FVC for the p-patient
            fvc = sub.FVC.values
            fvc=[float(val) for val in fvc]

            weeks = sub.Weeks.values
            weeks = [float(val) for val in weeks]

            slope_calc=float(slope_best.Calculated_Slope[slope_best.Patient == p])

            upper_CI = float(slope_best.Upper_CI[slope_best.Patient == p])

            lower_CI = float(slope_best.Lower_CI[slope_best.Patient == p])

            pred_slope=float(slope_best.Predicted_Slope[slope_best.Patient == p])

            slope, intercept, r_value, p_value, std_err = stats.linregress(weeks, fvc)

            if lower_CI < pred_slope < upper_CI:
                compare = 'Yes'
            else:
                compare = 'No'

            for w, fvc, in zip(weeks[1:], fvc[1:]):
                #Least Squares calculated FVC slope
                fvc_calculated = float(slope_calc*w + intercept)

                fvc_upperCI = float(upper_CI*w + intercept)

                fvc_lowerCI = float(lower_CI*w + intercept)

                fvc_predicted = float(pred_slope*w + intercept)

                fvc_plot = fvc_plot.append({'Patient': p, 'Week':w, 'FVC_true': fvc, 'FVC_OLS': fvc_calculated, 
                                            'FVC_upperCI': fvc_upperCI, 'FVC_lowerCI': fvc_lowerCI, 
                                            'FVC_predicted': fvc_predicted, 'Within_range': compare}, ignore_index = True)
    return fvc_plot

# %% [markdown]
# Calculate the total number of predicted slopes within the 95% CI

# %%
def slope_scores(slopes):
    
    total_in_CI = slopes.Within_Range[slopes.Within_Range=='Yes'].count()
    
    pct_in_CI = total_in_CI/slopes.shape[0]*100

    print('')
    print('Number of predicted in Slopes Within 95% CI of Least Squares Estimate')
    print(total_in_CI, 'correct', round(pct_in_CI, 1), '%')

# %% [markdown]
# ### Graphical Output Functions

# %% [markdown]
# Visualize Training Loss

# %%
def model_graph(model, start=0):
    mlp_mse = model.history['mse'][start:]
    mlp_val_mse = model.history['val_mse'][start:]
    mlp_loss = model.history['loss'][start:]
    mlp_val_loss = model.history['val_loss'][start:]

    epochs = range(1, len(mlp_mse) + 1)

    plt.plot(epochs, mlp_mse, 'bo', label='Training mse')
    plt.plot(epochs, mlp_val_mse, 'b', label='Validation mse')
    plt.title('Training and validation Mean Squared Error')
    plt.legend()

    plt.figure()

    plt.plot(epochs, mlp_loss, 'bo', label='Training loss')
    plt.plot(epochs, mlp_val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss (Mean Absolute Error)')
    plt.legend()

    plt.show()

# %% [markdown]
# Comparison between actual and predicted FVC

# %%
 def results_plot(scores, result='Yes'):
    patient = scores.Patient.unique()
    rows = int(len(patient)/4)
    plt.figure(figsize = (20,rows*5))

    counter = 1
    for p in patient:
        single_patient = scores[scores['Patient'] == p]
        if single_patient.Within_range.any() ==result:

            weeks = single_patient.Week
            true = single_patient.FVC_true
            OLS = single_patient.FVC_OLS
            upperCI = single_patient.FVC_upperCI
            lowerCI = single_patient.FVC_lowerCI
            pred = single_patient.FVC_predicted


            ax = plt.subplot(rows, 4, counter)

            plt.plot(weeks, pred, label = "Predicted", color='green', )
            plt.plot(weeks, true, label = "Actual", color='orange', marker='o')
            plt.plot(weeks, upperCI, label= 'Upper 95% CI', color = 'red')
            plt.plot(weeks, lowerCI, label= 'Lower 95% CI', color = 'red')

            plt.xlabel("Weeks", fontsize = 10)
            plt.ylabel("FVC",  fontsize = 10)
            plt.title(p)
            plt.legend(loc='lower right')
            counter+=1

# %% [markdown]
# ## Model Functions

# %% [markdown]
# ### 2D Convolutional Neural Net - CT Scans

# %%
def create_cnn_new(filters=(16, 32, 64), regress=False):
    # initialize the input shape and channel dimension, assuming
    # TensorFlow/channels-last ordering
    inputShape=(512, 512, 1)
    chanDim = -1

    # define the model input
    inputs = Input(shape=inputShape)

    # loop over the number of filters
    for (i, f) in enumerate(filters):
        # if this is the first CONV layer then set the input
        # appropriately
        if i == 0:
            x = inputs

        # CONV => RELU => BN => POOL
        x = Conv2D(f, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=chanDim)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)

    # flatten the volume, then FC => RELU => BN => DROPOUT
    x = Flatten()(x)
    x = Dense(16)(x)
    x = Activation("relu")(x)
    x = BatchNormalization(axis=chanDim)(x)
    x = Dropout(0.5)(x)

    # apply another FC layer, this one to match the number of nodes
    # coming out of the MLP
    x = Dense(4)(x)
    x = Activation("relu")(x)

    # check to see if the regression node should be added
    if regress:
        x = Dense(1, activation="linear")(x)

    # construct the CNN
    model = Model(inputs, x)

    # return the CNN
    return model

# %% [markdown]
# ### Multi-layer perceptron - Tabular Data

# %%
def create_mlp(dim, regress=False):
    # define our MLP network
    model = Sequential()
    model.add(Dense(8, input_dim=dim, activation="relu"))
    model.add(Dense(4, activation="relu"))

    # check to see if the regression node should be added
    if regress:
        model.add(Dense(1, activation="linear"))

    # return our model
    return model

# %% [markdown]
# ## Regression with CT Scans via 2D Convolutional Neural Net

# %% [markdown]
# We will use a convolutional neural network. Although we are using images, we are trying to predict a continous variable. Thus, we want the CNN to solve a regression problem.

# %% [markdown]
# ### Masked Images - Best Run

# %%
now = datetime.datetime.today().strftime('%Y-%m-%d-%H:%M:%S')

'./train.csv'
EPOCHS = 40
BATCH_SIZE = 8
CNN = create_cnn_new(regress=True)
callback = EarlyStopping(monitor='val_loss', patience=5)

cpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'./CNN/CNNmasked{now}.h5',
    monitor='val_loss', 
    verbose=1, 
    save_best_only=SAVE_BEST,
    mode='auto'
)

# rlp = tf.keras.callbacks.ReduceLROnPlateau(
#     monitor='val_loss', 
#     factor=0.5,
#     patience=5, 
#     verbose=1, 
#     min_lr=1e-8
# )

opt = Adam(lr = 0.0002)
CNN.compile(loss='mae',
              optimizer=opt,
              metrics=['mse'])

CNN.summary()

CNN_history = []

epochs=EPOCHS
CNN_fit = CNN.fit(masked_image_data(keys=train_ID, 
                               a = target, 
                               tab = TAB), 
                    steps_per_epoch = 500,
                    validation_data=masked_image_data(keys=test_ID, 
                               a = target, 
                               tab = TAB),
                    validation_steps = 250, 
                    callbacks = [callback, cpt], 
                    epochs=EPOCHS)

CNN_history.append(CNN_fit.history)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 512, 512, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 512, 512, 16)      160
# _________________________________________________________________
# activation (Activation)      (None, 512, 512, 16)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512, 512, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 16)                4194320
# _________________________________________________________________
# activation_3 (Activation)    (None, 16)                0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16)                64
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 68
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 4,218,201
# Trainable params: 4,217,945
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 500/500 [==============================] - ETA: 0s - loss: 1.1754 - mse: 2.4316
# Epoch 00001: val_loss improved from inf to 0.43955, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 58s 115ms/step - loss: 1.1754 - mse: 2.4316 - val_loss: 0.4395 - val_mse: 0.3132
# Epoch 2/40
# 500/500 [==============================] - ETA: 0s - loss: 0.7595 - mse: 1.0334
# Epoch 00002: val_loss improved from 0.43955 to 0.30907, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.7595 - mse: 1.0334 - val_loss: 0.3091 - val_mse: 0.1808
# Epoch 3/40
# 500/500 [==============================] - ETA: 0s - loss: 0.5429 - mse: 0.5371
# Epoch 00003: val_loss improved from 0.30907 to 0.26150, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 35s 71ms/step - loss: 0.5429 - mse: 0.5371 - val_loss: 0.2615 - val_mse: 0.0972
# Epoch 4/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.4061 - mse: 0.3111
# Epoch 00004: val_loss improved from 0.26150 to 0.23344, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 33s 65ms/step - loss: 0.4059 - mse: 0.3107 - val_loss: 0.2334 - val_mse: 0.0739
# Epoch 5/40
# 500/500 [==============================] - ETA: 0s - loss: 0.3071 - mse: 0.1754
# Epoch 00005: val_loss improved from 0.23344 to 0.16875, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 29s 58ms/step - loss: 0.3071 - mse: 0.1754 - val_loss: 0.1688 - val_mse: 0.0436
# Epoch 6/40
# 500/500 [==============================] - ETA: 0s - loss: 0.2310 - mse: 0.1061
# Epoch 00006: val_loss improved from 0.16875 to 0.13955, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 28s 55ms/step - loss: 0.2310 - mse: 0.1061 - val_loss: 0.1396 - val_mse: 0.0331
# Epoch 7/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1657 - mse: 0.0585
# Epoch 00007: val_loss improved from 0.13955 to 0.12952, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 27s 53ms/step - loss: 0.1657 - mse: 0.0585 - val_loss: 0.1295 - val_mse: 0.0332
# Epoch 8/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1333 - mse: 0.0374
# Epoch 00008: val_loss improved from 0.12952 to 0.12068, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1334 - mse: 0.0374 - val_loss: 0.1207 - val_mse: 0.0313
# Epoch 9/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1110 - mse: 0.0262
# Epoch 00009: val_loss did not improve from 0.12068
# 500/500 [==============================] - 24s 47ms/step - loss: 0.1111 - mse: 0.0262 - val_loss: 0.1308 - val_mse: 0.0471
# Epoch 10/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1102 - mse: 0.0245
# Epoch 00010: val_loss did not improve from 0.12068
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1101 - mse: 0.0245 - val_loss: 0.1218 - val_mse: 0.0309
# Epoch 11/40
# 500/500 [==============================] - ETA: 0s - loss: 0.1070 - mse: 0.0230
# Epoch 00011: val_loss improved from 0.12068 to 0.12054, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1070 - mse: 0.0230 - val_loss: 0.1205 - val_mse: 0.0301
# Epoch 12/40
# 500/500 [==============================] - ETA: 0s - loss: 0.1020 - mse: 0.0204
# Epoch 00012: val_loss did not improve from 0.12054
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1020 - mse: 0.0204 - val_loss: 0.1261 - val_mse: 0.0338
# Epoch 13/40
# 498/500 [============================>.] - ETA: 0s - loss: 0.0995 - mse: 0.0195
# Epoch 00013: val_loss did not improve from 0.12054
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0995 - mse: 0.0195 - val_loss: 0.1240 - val_mse: 0.0322
# Epoch 14/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0999 - mse: 0.0198
# Epoch 00014: val_loss improved from 0.12054 to 0.11974, saving model to ./CNN/CNNmasked2020-12-09-17:27:20.h5
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0998 - mse: 0.0197 - val_loss: 0.1197 - val_mse: 0.0318
# Epoch 15/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0954 - mse: 0.0177
# Epoch 00015: val_loss did not improve from 0.11974
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0955 - mse: 0.0177 - val_loss: 0.1276 - val_mse: 0.0331
# Epoch 16/40
# 498/500 [============================>.] - ETA: 0s - loss: 0.0981 - mse: 0.0188
# Epoch 00016: val_loss did not improve from 0.11974
# 500/500 [==============================] - 18s 37ms/step - loss: 0.0981 - mse: 0.0188 - val_loss: 0.1252 - val_mse: 0.0330
# Epoch 17/40
# 500/500 [==============================] - ETA: 0s - loss: 0.0959 - mse: 0.0179
# Epoch 00017: val_loss did not improve from 0.11974
# 500/500 [==============================] - 18s 37ms/step - loss: 0.0959 - mse: 0.0179 - val_loss: 0.1315 - val_mse: 0.0399
# Epoch 18/40
# 500/500 [==============================] - ETA: 0s - loss: 0.0941 - mse: 0.0169
# Epoch 00018: val_loss did not improve from 0.11974
# 500/500 [==============================] - 17s 35ms/step - loss: 0.0941 - mse: 0.0169 - val_loss: 0.1279 - val_mse: 0.0339
# Epoch 19/40
# 500/500 [==============================] - ETA: 0s - loss: 0.0922 - mse: 0.0161
# Epoch 00019: val_loss did not improve from 0.11974
# 500/500 [==============================] - 17s 35ms/step - loss: 0.0922 - mse: 0.0161 - val_loss: 0.1278 - val_mse: 0.0370

# %%
model_graph(CNN_fit, start=1)

# %%
CNN = load_model('./CNN/CNNmasked2020-12-09-17:27:20.h5')
# summarize model.
#mlp_predict.summary()

# %%
CNN_slope_per_pt = CNN_slope_per_pt = compare_slope_per_pt(CNN, 'image', image_type = 'masked', patient_IDs=test_ID, n_images=40)

# %%
slope_scores(CNN_slope_per_pt)
# Out:
# Number of predicted in Slopes Within 95% CI of Least Squares Estimate
# 24 correct 54.5 %

# %%
masked_graph = predictions_for_graph(CNN_slope_per_pt)

# %% [markdown]
# Positive Results

# %%
results_plot(masked_graph, result='Yes')

# %% [markdown]
# Negative Results

# %%
results_plot(masked_graph, result='No')

# %% [markdown]
# ### Best Run - CNN with Unmasked Images

# %%
now = datetime.datetime.today().strftime('%Y-%m-%d-%H:%M:%S')
now


# CNN Training - Tuning
'./train.csv'
EPOCHS = 40
BATCH_SIZE = 24
CNN = create_cnn_new(regress=True)
callback = EarlyStopping(monitor='val_loss', patience=5)

cpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'./CNN/CNN{now}.h5',
    monitor='val_loss', 
    verbose=1, 
    save_best_only=SAVE_BEST,
    mode='auto'
)

rlp = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5,
    patience=5, 
    verbose=1, 
    min_lr=1e-8
)

opt = Adam(lr=0.0002)
CNN.compile(loss='mae',
              optimizer=opt,
              metrics=['mse'])

CNN.summary()

CNN_history = []

epochs=EPOCHS
CNN_fit = CNN.fit(image_data(keys=train_ID, 
                               a = target, 
                               tab = TAB), 
                    steps_per_epoch = 500,
                    validation_data=image_data(keys=test_ID, 
                               a = target, 
                               tab = TAB),
                    validation_steps = 250, 
                    callbacks = [callback, rlp, cpt], 
                    epochs=EPOCHS)

CNN_history.append(CNN_fit.history)
# Out:
# Model: "functional_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 512, 512, 1)]     0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 512, 512, 16)      160
# _________________________________________________________________
# activation_30 (Activation)   (None, 512, 512, 16)      0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 512, 512, 16)      64
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 256, 256, 16)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 256, 256, 32)      4640
# _________________________________________________________________
# activation_31 (Activation)   (None, 256, 256, 32)      0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 128, 128, 64)      18496
# _________________________________________________________________
# activation_32 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                4194320
# _________________________________________________________________
# activation_33 (Activation)   (None, 16)                0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 16)                64
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 4)                 68
# _________________________________________________________________
# activation_34 (Activation)   (None, 4)                 0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 4,218,201
# Trainable params: 4,217,945
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.7164 - mse: 0.9942
# Epoch 00001: val_loss improved from inf to 0.82251, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 25s 50ms/step - loss: 0.7168 - mse: 0.9956 - val_loss: 0.8225 - val_mse: 1.0630
# Epoch 2/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.5323 - mse: 0.4985
# Epoch 00002: val_loss improved from 0.82251 to 0.42204, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 25s 49ms/step - loss: 0.5321 - mse: 0.4979 - val_loss: 0.4220 - val_mse: 0.2130
# Epoch 3/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.3903 - mse: 0.2724
# Epoch 00003: val_loss improved from 0.42204 to 0.25267, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.3900 - mse: 0.2720 - val_loss: 0.2527 - val_mse: 0.0968
# Epoch 4/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.3097 - mse: 0.1845
# Epoch 00004: val_loss improved from 0.25267 to 0.22982, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 25s 49ms/step - loss: 0.3096 - mse: 0.1844 - val_loss: 0.2298 - val_mse: 0.0866
# Epoch 5/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.2408 - mse: 0.1058
# Epoch 00005: val_loss improved from 0.22982 to 0.16177, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.2405 - mse: 0.1056 - val_loss: 0.1618 - val_mse: 0.0393
# Epoch 6/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.2015 - mse: 0.0728
# Epoch 00006: val_loss did not improve from 0.16177
# 500/500 [==============================] - 24s 48ms/step - loss: 0.2014 - mse: 0.0726 - val_loss: 0.1966 - val_mse: 0.0546
# Epoch 7/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1611 - mse: 0.0475
# Epoch 00007: val_loss improved from 0.16177 to 0.13355, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1611 - mse: 0.0474 - val_loss: 0.1335 - val_mse: 0.0325
# Epoch 8/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1386 - mse: 0.0354
# Epoch 00008: val_loss improved from 0.13355 to 0.13342, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1386 - mse: 0.0355 - val_loss: 0.1334 - val_mse: 0.0315
# Epoch 9/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1211 - mse: 0.0265
# Epoch 00009: val_loss improved from 0.13342 to 0.12773, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1211 - mse: 0.0264 - val_loss: 0.1277 - val_mse: 0.0309
# Epoch 10/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1086 - mse: 0.0217
# Epoch 00010: val_loss improved from 0.12773 to 0.12143, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1086 - mse: 0.0217 - val_loss: 0.1214 - val_mse: 0.0293
# Epoch 11/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1006 - mse: 0.0191
# Epoch 00011: val_loss improved from 0.12143 to 0.11653, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1006 - mse: 0.0190 - val_loss: 0.1165 - val_mse: 0.0275
# Epoch 12/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0934 - mse: 0.0167
# Epoch 00012: val_loss did not improve from 0.11653
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0934 - mse: 0.0168 - val_loss: 0.1188 - val_mse: 0.0288
# Epoch 13/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0896 - mse: 0.0154
# Epoch 00013: val_loss improved from 0.11653 to 0.11573, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 49ms/step - loss: 0.0896 - mse: 0.0154 - val_loss: 0.1157 - val_mse: 0.0276
# Epoch 14/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0876 - mse: 0.0145
# Epoch 00014: val_loss did not improve from 0.11573
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0875 - mse: 0.0144 - val_loss: 0.1169 - val_mse: 0.0309
# Epoch 15/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0809 - mse: 0.0126
# Epoch 00015: val_loss did not improve from 0.11573
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0810 - mse: 0.0127 - val_loss: 0.1187 - val_mse: 0.0299
# Epoch 16/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0755 - mse: 0.0115
# Epoch 00016: val_loss did not improve from 0.11573
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0755 - mse: 0.0115 - val_loss: 0.1235 - val_mse: 0.0327
# Epoch 17/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0761 - mse: 0.0115
# Epoch 00017: val_loss improved from 0.11573 to 0.11399, saving model to ./CNN/CNN2020-12-08-06:24:43.h5
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0761 - mse: 0.0115 - val_loss: 0.1140 - val_mse: 0.0291
# Epoch 18/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0738 - mse: 0.0107
# Epoch 00018: val_loss did not improve from 0.11399
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0738 - mse: 0.0107 - val_loss: 0.1190 - val_mse: 0.0302
# Epoch 19/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0702 - mse: 0.0099
# Epoch 00019: val_loss did not improve from 0.11399
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0702 - mse: 0.0099 - val_loss: 0.1205 - val_mse: 0.0304
# Epoch 20/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0652 - mse: 0.0086
# Epoch 00020: val_loss did not improve from 0.11399
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0653 - mse: 0.0086 - val_loss: 0.1191 - val_mse: 0.0312
# Epoch 21/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0652 - mse: 0.0088
# Epoch 00021: val_loss did not improve from 0.11399
# 500/500 [==============================] - 24s 49ms/step - loss: 0.0652 - mse: 0.0088 - val_loss: 0.1268 - val_mse: 0.0334
# Epoch 22/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0642 - mse: 0.0083
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 00022: val_loss did not improve from 0.11399
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0641 - mse: 0.0083 - val_loss: 0.1220 - val_mse: 0.0306

# %%
CNN = load_model('./CNN/CNN2020-12-08-06:24:43.h5')
# summarize model.
#mlp_predict.summary()

# %%
CNN_slope_per_pt = compare_slope_per_pt(CNN, 'image', image_type = 'unmasked', patient_IDs=test_ID, n_images=40)
slope_scores(CNN_slope_per_pt)
# Out:
# Number of predicted in Slopes Within 95% CI of Least Squares Estimate
# 32 correct 72.7 %

# %%
unmasked_graph = predictions_for_graph(CNN_slope_per_pt)

# %% [markdown]
# Positive Results

# %%
results_plot(unmasked_graph, result='Yes')

# %% [markdown]
# Negative Results

# %%
results_plot(unmasked_graph, result='No')

# %% [markdown]
# ## Regression with Tabular Data via Multi-Layer Perceptron

# %% [markdown]
# ### Running MLP with Sequence

# %%
now = datetime.datetime.today().strftime('%Y-%m-%d-%H:%M:%S')


EPOCHS = 40
BATCH_SIZE = 24

mlp = create_mlp(6, regress=True)
callback = EarlyStopping(monitor='val_loss', patience=3)

cpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'./MLP/MLP{now}.h5',
    monitor='val_loss', 
    verbose=1, 
    save_best_only=SAVE_BEST,
    mode='auto'
)

opt = Adam(lr=0.0002)

mlp.compile(loss='mae', optimizer=opt, metrics=['mse'])
mlp.summary()

mlp_history = []

print("[INFO] training model...")

# mlp_fit = mlp.fit(x=train_tab, y=train_target, 
#                   validation_data=(test_tab, test_target), epochs=40, batch_size=24, callbacks=[callback])

mlp_fit = mlp.fit(tab_data(keys=train_ID, 
                               a = target, 
                               tab = TAB), 
                    steps_per_epoch = 500,
                    validation_data=tab_data(keys=test_ID, 
                               a = target, 
                               tab = TAB),
                    validation_steps = 250, 
                    callbacks = [callback, cpt], 
                    epochs=EPOCHS)

mlp_history.append(mlp_fit.history)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 56
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 97
# Trainable params: 97
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1235 - mse: 0.0270
# Epoch 00001: val_loss improved from inf to 0.13026, saving model to ./MLP/MLP40.h5
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1234 - mse: 0.0269 - val_loss: 0.1303 - val_mse: 0.0315
# Epoch 2/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1052 - mse: 0.0193
# Epoch 00002: val_loss improved from 0.13026 to 0.12707, saving model to ./MLP/MLP40.h5
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1052 - mse: 0.0193 - val_loss: 0.1271 - val_mse: 0.0309
# Epoch 3/40
# 500/500 [==============================] - ETA: 0s - loss: 0.1029 - mse: 0.0186
# Epoch 00003: val_loss improved from 0.12707 to 0.12657, saving model to ./MLP/MLP40.h5
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1029 - mse: 0.0186 - val_loss: 0.1266 - val_mse: 0.0316
# Epoch 4/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1033 - mse: 0.0189
# Epoch 00004: val_loss did not improve from 0.12657
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1033 - mse: 0.0189 - val_loss: 0.1291 - val_mse: 0.0334
# Epoch 5/40
# 500/500 [==============================] - ETA: 0s - loss: 0.1022 - mse: 0.0185
# Epoch 00005: val_loss did not improve from 0.12657
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1022 - mse: 0.0185 - val_loss: 0.1304 - val_mse: 0.0339
# Epoch 6/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1010 - mse: 0.0181
# Epoch 00006: val_loss did not improve from 0.12657
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1010 - mse: 0.0181 - val_loss: 0.1279 - val_mse: 0.0328

# %%
MLP = load_model('./MLP/MLP40.h5')

# %%
mlp_slope_per_pt = compare_slope_per_pt(MLP, 'text', image_type = 'unmasked', patient_IDs=test_ID, n_images=40)
slope_scores(mlp_slope_per_pt)
# Out:
# Number of predicted in Slopes Within 95% CI of Least Squares Estimate
# 25 correct 56.8 %

# %% [markdown]
# ## Combined Model

# %% [markdown]
# Run the combined model incoprorating multi-layer perceptron for tabular data and CNN for image data

# %%
now = datetime.datetime.today().strftime('%Y-%m-%d-%H:%M:%S')


EPOCHS = 40
BATCH_SIZE = 24

# def step_decay(epoch):
#    initial_lrate = 0.0001
#    drop = 0.5
#    epochs_drop = 3
#    lrate = initial_lrate * math.pow(drop,  
#            math.floor((1+epoch)/epochs_drop))
#    return lrate

mlp = create_mlp(6, regress=False)
cnn = create_cnn_new(regress=False)

combinedInput = concatenate([cnn.output, mlp.output])

x = Dense(4, activation="relu")(combinedInput)
x = Dense(1, activation="linear")(x)

Combined = Model(inputs=[cnn.input, mlp.input], outputs=x)

opt = Adam(lr=0.0002)

callback = EarlyStopping(monitor='val_loss', patience=10)

cpt = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'./combined/combined{now}.h5',
    monitor='val_loss', 
    verbose=1, 
    save_best_only=SAVE_BEST,
    mode='auto')

Combined.compile(loss='mae', optimizer=opt, metrics=['mse'])

Combined.summary()

model_history = []

Combined_fit = Combined.fit(combined_data(keys=train_ID, 
                               a = target, 
                               tab = TAB), 
                    steps_per_epoch = 500,
                    validation_data=combined_data(keys=test_ID, 
                               a = target, 
                               tab = TAB),
                    validation_steps = 250, 
                    callbacks = [callback, cpt], 
                    epochs=EPOCHS)

model_history.append(Combined_fit.history)
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 512, 512, 16) 160         input_9[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 512, 512, 16) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 512, 512, 16) 64          activation_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 256, 256, 16) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 32) 4640        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 256, 256, 32) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 256, 256, 32) 128         activation_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 128, 128, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 128, 128, 64) 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 128, 64) 256         activation_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 64, 64, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 262144)       0           max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 16)           4194320     flatten_8[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16)           0           dense_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16)           64          activation_43[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16)           0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# dense_27_input (InputLayer)     [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 4)            68          dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 8)            56          dense_27_input[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4)            0           dense_30[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 4)            36          dense_27[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8)            0           activation_44[0][0]
#                                                                  dense_28[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 4)            36          concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1)            5           dense_31[0][0]
# ==================================================================================================
# Total params: 4,218,329
# Trainable params: 4,218,073
# Non-trainable params: 256
# __________________________________________________________________________________________________
# Epoch 1/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.3115 - mse: 0.1575
# Epoch 00001: val_loss improved from inf to 0.18416, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 25s 49ms/step - loss: 0.3113 - mse: 0.1573 - val_loss: 0.1842 - val_mse: 0.0527
# Epoch 2/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1872 - mse: 0.0605
# Epoch 00002: val_loss improved from 0.18416 to 0.15513, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1871 - mse: 0.0604 - val_loss: 0.1551 - val_mse: 0.0415
# Epoch 3/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1481 - mse: 0.0411
# Epoch 00003: val_loss improved from 0.15513 to 0.14352, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1482 - mse: 0.0412 - val_loss: 0.1435 - val_mse: 0.0387
# Epoch 4/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1271 - mse: 0.0292
# Epoch 00004: val_loss improved from 0.14352 to 0.13419, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1271 - mse: 0.0292 - val_loss: 0.1342 - val_mse: 0.0362
# Epoch 5/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1138 - mse: 0.0232
# Epoch 00005: val_loss did not improve from 0.13419
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1140 - mse: 0.0232 - val_loss: 0.1345 - val_mse: 0.0337
# Epoch 6/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1058 - mse: 0.0205
# Epoch 00006: val_loss improved from 0.13419 to 0.12432, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1058 - mse: 0.0204 - val_loss: 0.1243 - val_mse: 0.0319
# Epoch 7/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1023 - mse: 0.0190
# Epoch 00007: val_loss did not improve from 0.12432
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1024 - mse: 0.0190 - val_loss: 0.1332 - val_mse: 0.0327
# Epoch 8/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.1017 - mse: 0.0189
# Epoch 00008: val_loss did not improve from 0.12432
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1016 - mse: 0.0189 - val_loss: 0.1326 - val_mse: 0.0328
# Epoch 9/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0989 - mse: 0.0182
# Epoch 00009: val_loss did not improve from 0.12432
# 500/500 [==============================] - 24s 49ms/step - loss: 0.0988 - mse: 0.0182 - val_loss: 0.1296 - val_mse: 0.0329
# Epoch 10/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0941 - mse: 0.0166
# Epoch 00010: val_loss did not improve from 0.12432
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0942 - mse: 0.0166 - val_loss: 0.1334 - val_mse: 0.0336
# Epoch 11/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0932 - mse: 0.0163
# Epoch 00011: val_loss improved from 0.12432 to 0.12189, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0932 - mse: 0.0164 - val_loss: 0.1219 - val_mse: 0.0293
# Epoch 12/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0908 - mse: 0.0155
# Epoch 00012: val_loss did not improve from 0.12189
# 500/500 [==============================] - 25s 49ms/step - loss: 0.0908 - mse: 0.0155 - val_loss: 0.1257 - val_mse: 0.0329
# Epoch 13/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0889 - mse: 0.0153
# Epoch 00013: val_loss improved from 0.12189 to 0.11848, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0888 - mse: 0.0153 - val_loss: 0.1185 - val_mse: 0.0293
# Epoch 14/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0851 - mse: 0.0139
# Epoch 00014: val_loss did not improve from 0.11848
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0852 - mse: 0.0139 - val_loss: 0.1233 - val_mse: 0.0314
# Epoch 15/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0864 - mse: 0.0144
# Epoch 00015: val_loss did not improve from 0.11848
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0864 - mse: 0.0144 - val_loss: 0.1233 - val_mse: 0.0306
# Epoch 16/40
# 500/500 [==============================] - ETA: 0s - loss: 0.0868 - mse: 0.0143
# Epoch 00016: val_loss improved from 0.11848 to 0.11773, saving model to ./combined/combined2020-12-08-06:41:31.h5
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0868 - mse: 0.0143 - val_loss: 0.1177 - val_mse: 0.0289
# Epoch 17/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0823 - mse: 0.0129
# Epoch 00017: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 49ms/step - loss: 0.0823 - mse: 0.0129 - val_loss: 0.1292 - val_mse: 0.0330
# Epoch 18/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0840 - mse: 0.0136
# Epoch 00018: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0840 - mse: 0.0136 - val_loss: 0.1236 - val_mse: 0.0304
# Epoch 19/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0821 - mse: 0.0131
# Epoch 00019: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0821 - mse: 0.0131 - val_loss: 0.1254 - val_mse: 0.0325
# Epoch 20/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0836 - mse: 0.0133
# Epoch 00020: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0837 - mse: 0.0133 - val_loss: 0.1249 - val_mse: 0.0322
# Epoch 21/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0835 - mse: 0.0135
# Epoch 00021: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0835 - mse: 0.0135 - val_loss: 0.1276 - val_mse: 0.0324
# Epoch 22/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0859 - mse: 0.0139
# Epoch 00022: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0860 - mse: 0.0139 - val_loss: 0.1259 - val_mse: 0.0327
# Epoch 23/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0853 - mse: 0.0138
# Epoch 00023: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0853 - mse: 0.0138 - val_loss: 0.1251 - val_mse: 0.0321
# Epoch 24/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0823 - mse: 0.0132
# Epoch 00024: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0822 - mse: 0.0132 - val_loss: 0.1257 - val_mse: 0.0333
# Epoch 25/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0842 - mse: 0.0137
# Epoch 00025: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0842 - mse: 0.0137 - val_loss: 0.1263 - val_mse: 0.0329
# Epoch 26/40
# 499/500 [============================>.] - ETA: 0s - loss: 0.0793 - mse: 0.0123
# Epoch 00026: val_loss did not improve from 0.11773
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0794 - mse: 0.0123 - val_loss: 0.1226 - val_mse: 0.0313

# %%
model_graph(Combined_fit, start=0)

# %%
Combined = load_model('./combined/combined2020-12-06-09:30:40.h5')

# %%
combined_slope_per_pt = compare_slope_per_pt(Combined, 'combined', image_type = 'unmasked', patient_IDs=test_ID, n_images=40)
slope_scores(combined_slope_per_pt)
# Out:
# Number of predicted in Slopes Within 95% CI of Least Squares Estimate
# 29 correct 65.9 %

# %%
combined_graph = predictions_for_graph(combined_slope_per_pt)

# %% [markdown]
# Positive Results

# %%
results_plot(combined_graph, result='Yes')

# %% [markdown]
# Negative Results

# %%
results_plot(combined_graph, result='No')
